# %%
from common import Node,take_input_better,print_LL

head= take_input_better()
print_LL(head)
def insert_at_head(head,data):
    newNode= Node(data)
    newNode.next = head 
    head= newNode
    return head
def insert_at_tail(head,data):
    newNode= Node(data)
    if head==None:
        return newNode
    temp = head
    while temp.next!= None:
        temp = temp.next
    temp.next = newNode
    return head
def insert_tail_recuresion(head,data):
    
    if head==None:
        return Node(data)
    head.next = insert_tail_recuresion(head.next,data)
    return
def insert_at_index(head,data,index):
    if index==0:
        return insert_at_head(head,data)
    newnode = Node(data)
    temp = head
    count = 0
    
    while temp != None and count<index-1:
        temp = temp.next
        count+=1
        
    newnode.next = temp.next
    temp.next= newnode
    
def insert_at_index_recursively(head,data,index):
    if index==0:
        return insert_at_head(head,data)
    if head==None:
        print("Index is out of bounds")
        return head
    head.next= insert_at_index_recursively(head.next,data,index-1)
    return head
    
    
    
    
# head= insert_at_tail(head,100)
# head = insert_tail_recuresion(head,100)
# print("\nDown here")
# print_LL(head)

# head1= insert_at_index(head,35,3)
# print("aftert inserting at index")
# print_LL(head)

def delete_at_index(head):
    if head==None:
        return None
    newhead= head.next
    return newhead

# print_LL(head)
# 
# head1= delete_at_index(head)
# print("aftert del at index")
# print_LL(head)

def is_tail_node(node):
    if node==None:
        return None
    if node.next==None:
        return True
    return False


def delete_at_tail(head):
    if head==None or head.next is None:
        return None
    
    temp = head
    while (temp.next.next is not None):
        temp = temp.next
        
    temp.next = None
    return head

def delete_tail_recursive(head):
    if head==None:
        return None
    if head.next is None:
        return None
    
    head.next= delete_tail_recursive(head.next)
    return head
    
        
    
def delte_at_index(head,index):
    if head==None:
        return head
    if index==0:
        return head.next
    temp = head
    count = 0
    while (temp !=None and count<index-1):
        temp = temp.next
        count +=1
    if temp ==None or temp.next==None:
        return head
    temp.next = temp.next.next
    return head

def delete_at_index_recursively(head,index):
    if head==None:
        return head
    if index==0:
        return head.next
    head.next = delete_at_index_recursively(head.next,index-1)
    return head

def delete_by_value(head,value):
    if head==None:
        return None
    if head.data==value:
        return head.next
    
    temp = head
    while temp.next !=None and temp.next.data !=value:
        temp = temp.next
        
    if temp.next is None:
        return head
        
    temp.next = temp.next.next
    return head
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from common import Node,take_input_better,print_LL
#       3 head= take_input_better()
#       4 print_LL(head)
#
# File c:\Users\saiki\OneDrive\Desktop\Python Dsa\Krish-Naik,Mayank agarwal_udmey course\linked_list\common.py:41
#      38         value = int(input("Enter the value of node"))
#      39     return head
# ---> 41 newhead= take_input_better()
#      42 print_LL(newhead)
#      44 ##Take input of linjked list
#      45
#      46
#      47 ##return a head to bnewly created linked list
#
# File c:\Users\saiki\OneDrive\Desktop\Python Dsa\Krish-Naik,Mayank agarwal_udmey course\linked_list\common.py:19, in take_input_better()
#      18 def take_input_better():
# ---> 19     value = int(input("Enter a number"))
#      20     head = None
#      21     tail = None
#
# ValueError: invalid literal for int() with base 10: '-1-1-'
